# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r'C:\\Users\\Cognitive\\Data Science Assignment\\Data II'

# %%
all_files=glob.glob(path+'/*xls')

# %%
df=pd.read_excel(all_files[1],index_col=None,header=0)
df2=pd.read_excel(all_files[0],index_col=None,header=0)
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
pd.read_excel(all_files[0],index_col=None,header=0)
# Out:
#                                  2014-15        Unnamed: 1 Unnamed: 2  \
# Item               Per Capita GSDP (Rs.)  Population ('00)    Primary
# States                               NaN               NaN        NaN
#  Maharashtra                      152853           1172450   21758383
# Andhra Pradesh                    104977            501510   16303716
# Arunachal Pradesh                 112718             14870     716959
# Assam                              60621            326780    5326697
# Bihar                              33954           1101240    8019997
# Chattisgarh                        86860            270530    6400817
# Goa                               271793             14950     312129
# Gujarat                           141263            633590   15887187
# Haryana                           164077            266620    8040424
# Himachal Pradesh                  147330             70840    1548366
# ...

# %%
df=df.iloc[:,[1,3,7,10,13]]
df=df.dropna(axis=0,how="all")
df=df.dropna(axis=1,how="all")

# %%
df.columns.values[0]="States"

# %%
df
# Out:
#                   States  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0          A & N Islands                 1.21                       1.69
# 1         Andhra Pradesh                 4.35                       5.20
# 2      Arunachal Pradesh                10.89                       6.71
# 3                  Assam                 7.44                      10.51
# 4                  Bihar                 2.09                       4.08
# 5             Chandigarh                  NaN                       0.44
# 6            Chhatisgarh                 1.42                       5.85
# 7   Dadra & Nagar Haveli                 1.57                       4.02
# 8            Daman & Diu                 0.85                       3.11
# 9                  Delhi                  NaN                       0.76
# 10                   Goa                 0.20                       0.07
# 11               Gujarat                 0.76                       6.41
# ...

# %%
df2=df2.reset_index()

# %%
df2.columns.values[1]="States"
df2.columns.values[2]="Per Capita GSDP(2014-15)"
df2.columns.values[3]="Population"
df2.columns.values[4]="Primary"
df2.columns.values[5]="Secondary"
df2.columns.values[6]="Tertiary"
df2.columns.values[7]="%Primary"
df2.columns.values[8]="%Secondary"
df2.columns.values[9]="%Tertiary"
df2
# Out:
#     level_0             States Per Capita GSDP(2014-15)        Population  \
# 0         0               Item    Per Capita GSDP (Rs.)  Population ('00)
# 1         1             States                      NaN               NaN
# 2         2        Maharashtra                   152853           1172450
# 3         3     Andhra Pradesh                   104977            501510
# 4         4  Arunachal Pradesh                   112718             14870
# 5         5              Assam                    60621            326780
# 6         6              Bihar                    33954           1101240
# 7         7        Chattisgarh                    86860            270530
# 8         8                Goa                   271793             14950
# 9         9            Gujarat                   141263            633590
# 10       10            Haryana                   164077            266620
# 11       11   Himachal Pradesh                   147330             70840
# ...

# %%
df2=df2.drop([0])
df2=df2.drop([1])

# %%
#merging dataframes
new_df=pd.merge(df,df2,how="inner",on=['States'])

# %%
new_df=new_df.drop("level_0",axis=1)

# %%
new_df
# Out:
#                States  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0      Andhra Pradesh                 4.35                       5.20
# 1   Arunachal Pradesh                10.89                       6.71
# 2               Assam                 7.44                      10.51
# 3               Bihar                 2.09                       4.08
# 4                 Goa                 0.20                       0.07
# 5             Gujarat                 0.76                       6.41
# 6             Haryana                 0.41                       5.81
# 7    Himachal Pradesh                 0.46                       0.87
# 8           Karnataka                 2.32                       3.85
# 9              Kerala                  NaN                        NaN
# 10            Manipur                18.00                       4.20
# 11          Meghalaya                10.34                       6.52
# ...

# %%
#slicing data to find correlation
new_cor=new_df
new_cor=new_cor.iloc[:,[0,1,2,3,5]]
new_cor=new_cor.corr()

# %%
#plotting correlation
pd.scatter_matrix(new_cor, figsize=(8, 8))
plt.show()
plt.savefig('correlation1.png')
# Out:
# C:\Users\Cognitive\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %%
#finding correlation
population_cor=new_df
popultion_cor=population_cor.iloc[:,[0,1,2,3,6]]
popultion_cor=popultion_cor.corr()
popultion_cor
# Out:
#                            Primary - 2014-2015  Upper Primary - 2014-2015  \
# Primary - 2014-2015                   1.000000                   0.429206
# Upper Primary - 2014-2015             0.429206                   1.000000
# Secondary - 2014-2015                 0.063110                   0.437064
#
#                            Secondary - 2014-2015
# Primary - 2014-2015                     0.063110
# Upper Primary - 2014-2015               0.437064
# Secondary - 2014-2015                   1.000000

# %%
#plotting correlation
plt.matshow(popultion_cor)

plt.xticks(range(len(popultion_cor.columns)),popultion_cor.columns)
plt.yticks(range(len(popultion_cor.columns)), popultion_cor.columns)
plt.colorbar()
plt.show()
plt.savefig('correlation2.png')

# %%
#finding correlation
primary_cor=new_df
primary_cor=primary_cor.iloc[:,[1,10,11,12]]
primary_cor=primary_cor.corr()

# %%
#plotting corealtion
mask = np.zeros_like(primary_cor, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(primary_cor, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5)
plt.savefig('correlation3.png')

# %%
# finding correlation
uprimary_cor=new_df
uprimary_cor=uprimary_cor.iloc[:,[2,10,11,12]]
uprimary=uprimary_cor.corr()
uprimary
# Out:
#                            Upper Primary - 2014-2015  %Primary  %Secondary  \
# Upper Primary - 2014-2015                   1.000000  0.229565    0.460274
# %Primary                                    0.229565  1.000000    0.360336
# %Secondary                                  0.460274  0.360336    1.000000
# %Tertiary                                  -0.415631 -0.514415   -0.637709
#
#                            %Tertiary
# Upper Primary - 2014-2015  -0.415631
# %Primary                   -0.514415
# %Secondary                 -0.637709
# %Tertiary                   1.000000

# %%
#plotting correlation

f, ax = plt.subplots(figsize=(6,6))
heatmap = sns.heatmap(uprimary, linewidths = .5)
#add the column names as labels
ax.set_yticklabels(uprimary.columns, rotation = 0)
ax.set_xticklabels(uprimary.columns)
plt.savefig('correlation4.png')

# %%
#finding correlation
secondary_cor=new_df
secondary_cor=secondary_cor.iloc[:,[3,10,11,12]]
seconday_cor=secondary_cor.corr()
seconday_cor
# Out:
#                        Secondary - 2014-2015  %Primary  %Secondary  %Tertiary
# Secondary - 2014-2015               1.000000  0.364470    0.259032  -0.235999
# %Primary                            0.364470  1.000000    0.360336  -0.514415
# %Secondary                          0.259032  0.360336    1.000000  -0.637709
# %Tertiary                          -0.235999 -0.514415   -0.637709   1.000000

# %%
#plotting correlation
pd.scatter_matrix(seconday_cor, figsize=(8, 8))
plt.show()
plt.savefig('correlation5.png')
# Out:
# C:\Users\Cognitive\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %%
#finding correlation
ssecondary_cor=new_df
ssecondary_cor=ssecondary_cor.iloc[:,[4,10,11,12]]
ssecondary=ssecondary_cor.corr()
ssecondary=ssecondary_cor.corr()

# %%
#plotting correlation
heatmap = sns.heatmap(ssecondary, linewidths = .5)
#add the column names as labels
ax.set_yticklabels(ssecondary.columns, rotation = 0)
ax.set_xticklabels(ssecondary.columns)
plt.savefig('correlation6.png')
